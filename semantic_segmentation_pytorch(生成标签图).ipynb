# %% [markdown]
# <a href="https://colab.research.google.com/github/jjandnn/semantic-segmentation-pytorch/blob/master/semantic_segmentation_pytorch(%E7%94%9F%E6%88%90%E6%A0%87%E7%AD%BE%E5%9B%BE).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/drive/My Drive
# !git clone https://github.com/CSAILVision/semantic-segmentation-pytorch.git
# %cd /content/drive/My Drive/semantic-segmentation-pytorch
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !mkdir images results
# # 把高级的两个模型都下了
# !wget -P ade20k-resnet101dilated-ppm_deepsup http://sceneparsing.csail.mit.edu/model/pytorch/ade20k-resnet101dilated-ppm_deepsup/encoder_epoch_25.pth
# !wget -P ade20k-resnet101dilated-ppm_deepsup http://sceneparsing.csail.mit.edu/model/pytorch/ade20k-resnet101dilated-ppm_deepsup/decoder_epoch_25.pth
# !wget -P ade20k-resnet101-upernet http://sceneparsing.csail.mit.edu/model/pytorch/ade20k-resnet101-upernet/encoder_epoch_50.pth
# !wget -P ade20k-resnet101-upernet http://sceneparsing.csail.mit.edu/model/pytorch/ade20k-resnet101-upernet/decoder_epoch_50.pth
# !wget -P ade20k-hrnetv2-c1 http://sceneparsing.csail.mit.edu/model/pytorch/ade20k-hrnetv2-c1/decoder_epoch_30.pth
# !wget -P ade20k-hrnetv2-c1 http://sceneparsing.csail.mit.edu/model/pytorch/ade20k-hrnetv2-c1/encoder_epoch_30.pth
# !bash Miniconda3-latest-Linux-x86_64.sh -bfp /usr/local
import sys
sys.path +=['/usr/local/lib/python3.7/site-packages','/content/drive/My Drive/semantic-segmentation-pytorch']
# !conda install pytorch==1.1.0 torchvision==0.2.1 cudatoolkit=10.0 -c pytorch -y
# !conda install pytorch==1.1.0 torchvision==0.3.0 cudatoolkit=10.0 -c pytorch -y
# !conda install -c conda-forge yacs pillow=6.2.1 -y
# !pip install opencv-python ffmpeg-python scipy==1.3
# !sudo apt install axel
# Out:
# /content/drive/My Drive
# Cloning into 'semantic-segmentation-pytorch'...
# remote: Enumerating objects: 1036, done.
# remote: Total 1036 (delta 0), reused 0 (delta 0), pack-reused 1036
# Receiving objects: 100% (1036/1036), 3.99 MiB | 13.80 MiB/s, done.
# Resolving deltas: 100% (633/633), done.
# /content/drive/My Drive/semantic-segmentation-pytorch
# --2020-04-28 06:34:24--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>]  81.12M  73.0MB/s    in 1.1s
#
# 2020-04-28 06:34:25 (73.0 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# ...

# %%
# # test ade20k-resnet50dilated-ppm_deepsup (含下载基础模型ade20k-resnet50dilated-ppm_deepsup)
# !sh ./demo_test.sh

# %%
# 基础模型ade20k-resnet50dilated-ppm_deepsup测试（写清楚文件夹，TEST.xxxxx这是yaml的格式，自己查yaml中的参数设置，可以改参数）
# !python3 -u test.py \
  --imgs images/ADE_val_00001519.jpg \
  --cfg config/ade20k-resnet50dilated-ppm_deepsup.yaml \
  DIR ade20k-resnet50dilated-ppm_deepsup \
  TEST.result results/ \
  TEST.checkpoint epoch_20.pth
# Out:
# [2020-04-28 07:58:10,957 INFO test.py line 172 4387] Loaded configuration file config/ade20k-resnet50dilated-ppm_deepsup.yaml
# [2020-04-28 07:58:10,957 INFO test.py line 173 4387] Running with config:
# DATASET:
#   imgMaxSize: 1000
#   imgSizes: (300, 375, 450, 525, 600)
#   list_train: ./data/training.odgt
#   list_val: ./data/validation.odgt
#   num_class: 150
#   padding_constant: 8
#   random_flip: True
#   root_dataset: ./data/
#   segm_downsampling_rate: 8
# DIR: ade20k-resnet50dilated-ppm_deepsup
# MODEL:
#   arch_decoder: ppm_deepsup
#   arch_encoder: resnet50dilated
#   fc_dim: 2048
#   weights_decoder:
#   weights_encoder:
# TEST:
#   batch_size: 1
#   checkpoint: epoch_20.pth
#   result: results/
# TRAIN:
#   batch_size_per_gpu: 2
#   beta1: 0.9
#   deep_sup_scale: 0.4
#   disp_iter: 20
#   epoch_iters: 5000
#   fix_bn: False
#   lr_decoder: 0.02
#   lr_encoder: 0.02
#   lr_pow: 0.9
#   num_epoch: 20
#   optim: SGD
#   seed: 304
#   start_epoch: 0
# ...

# %%
# # resnet101 TEST.xxxxx这是yaml的格式，自己查yaml中的参数设置，可以改参数
# # 这个模型太一般
# !python3 -u test.py \
#   --imgs images/ADE_val_00001519.jpg \
#   --cfg config/ade20k-resnet101dilated-ppm_deepsup.yaml \
#   DIR ade20k-resnet101dilated-ppm_deepsup \
#   TEST.result results/ \
#   TEST.checkpoint epoch_25.pth

# %%
# 排名第二的模型resnet101 + upernet
# !python3 -u test.py \
  --imgs images/ADE_val_00001519.jpg \
  --cfg config/ade20k-resnet101-upernet.yaml \
  DIR ade20k-resnet101-upernet \
  TEST.result results/ \
  TEST.checkpoint epoch_50.pth
# Out:
# [2020-04-28 07:55:23,089 INFO test.py line 172 4317] Loaded configuration file config/ade20k-resnet101-upernet.yaml
# [2020-04-28 07:55:23,090 INFO test.py line 173 4317] Running with config:
# DATASET:
#   imgMaxSize: 1000
#   imgSizes: (300, 375, 450, 525, 600)
#   list_train: ./data/training.odgt
#   list_val: ./data/validation.odgt
#   num_class: 150
#   padding_constant: 32
#   random_flip: True
#   root_dataset: ./data/
#   segm_downsampling_rate: 4
# DIR: ade20k-resnet101-upernet
# MODEL:
#   arch_decoder: upernet
#   arch_encoder: resnet101
#   fc_dim: 2048
#   weights_decoder:
#   weights_encoder:
# TEST:
#   batch_size: 1
#   checkpoint: epoch_50.pth
#   result: results/
# TRAIN:
#   batch_size_per_gpu: 2
#   beta1: 0.9
#   deep_sup_scale: 0.4
#   disp_iter: 20
#   epoch_iters: 5000
#   fix_bn: False
#   lr_decoder: 0.02
#   lr_encoder: 0.02
#   lr_pow: 0.9
#   num_epoch: 40
#   optim: SGD
#   seed: 304
#   start_epoch: 0
#   weight_decay: 0.0001
#   workers: 16
# VAL:
# ...

# %%
# hrnetv2 最牛逼的模型的测试，TEST.xxxxx这是yaml的格式，自己查yaml中的参数设置，可以改参数
# !python3 -u test.py \
  --imgs images/ADE_val_00001519.jpg \
  --cfg config/ade20k-hrnetv2.yaml \
  DIR ade20k-hrnetv2-c1 \
  TEST.result results/ \
  TEST.checkpoint epoch_30.pth
# Out:
# [2020-04-28 07:39:21,326 INFO test.py line 172 4023] Loaded configuration file config/ade20k-hrnetv2.yaml
# [2020-04-28 07:39:21,326 INFO test.py line 173 4023] Running with config:
# DATASET:
#   imgMaxSize: 1000
#   imgSizes: (300, 375, 450, 525, 600)
#   list_train: ./data/training.odgt
#   list_val: ./data/validation.odgt
#   num_class: 150
#   padding_constant: 32
#   random_flip: True
#   root_dataset: ./data/
#   segm_downsampling_rate: 4
# DIR: ade20k-hrnetv2-c1
# MODEL:
#   arch_decoder: c1
#   arch_encoder: hrnetv2
#   fc_dim: 720
#   weights_decoder:
#   weights_encoder:
# TEST:
#   batch_size: 1
#   checkpoint: epoch_30.pth
#   result: results/
# TRAIN:
#   batch_size_per_gpu: 2
#   beta1: 0.9
#   deep_sup_scale: 0.4
#   disp_iter: 20
#   epoch_iters: 5000
#   fix_bn: False
#   lr_decoder: 0.02
#   lr_encoder: 0.02
#   lr_pow: 0.9
#   num_epoch: 30
#   optim: SGD
#   seed: 304
#   start_epoch: 0
#   weight_decay: 0.0001
#   workers: 16
# VAL:
#   batch_size: 1
# ...
